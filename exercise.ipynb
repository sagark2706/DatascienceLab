# %%
import pandas as pd
import numpy as abu

# %%
dic = {
    'name':['Niranjan','Aswin','Abu','Sagar',abu.nan],
    'Age':[abu.nan,23,45,11,67],
    'Brach':['BCA','MCA','BCA',abu.nan,'MCA']
}

# %%
kk = abu.array(dic)

# %%
print(kk)
# Out:
# {'name': ['Niranjan', 'Aswin', 'Abu', 'Sagar', nan], 'Age': [nan, 23, 45, 11, 67], 'Brach': ['BCA', 'MCA', 'BCA', nan, 'MCA']}

# %%
x = pd.DataFrame(dic).fillna(1)

# %%
print(x.set_index('Age'))
# Out:
#           name Brach
# Age
# 1.0   Niranjan   BCA
# 23.0     Aswin   MCA
# 45.0       Abu   BCA
# 11.0     Sagar     1
# 67.0         1   MCA

# %%
print(x.groupby('Brach')['Age'].mean())
# Out:
# Brach
# 1      11.0
# BCA    23.0
# MCA    45.0
# Name: Age, dtype: float64

# %%
pp = {
    'cname':['Apple','Meta','Google','IBM'],
    'Profit':[-10,200,-200,100]
}
d = pd.DataFrame(pp)

# %%
print(d)
# Out:
#     cname  Profit
# 0   Apple     -10
# 1    Meta     200
# 2  Google    -200
# 3     IBM     100

# %%
print(d['Profit'].apply(lambda x:x>0))
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# Name: Profit, dtype: bool

# %%
one = pd.read_csv('e1.csv')

# %%
print(one)
# Out:
#    eid ename  stipend
# 0    1  amal      399
# 1    2   abu      499
# 2    3  sagu      500

# %%
two = pd.read_csv('e2.csv')

# %%
th = pd.merge(one,two,how='inner',on='eid')

# %%
print(th)
# Out:
#    eid ename  stipend position
# 0    1  amal      399       pr
# 1    2   abu      499       hr
# 2    3  sagu      500       gr

# %%
import matplotlb.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [16], line 1
# ----> 1 import matplotlb.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlb'

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/njck/.local/lib/python3.10/site-packages/pip/_internal/utils/logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "/home/njck/.local/lib/python3.10/site-packages/pip/_vendor/rich/console.py", line 1673, in print
#     extend(render(renderable, render_options))
#   File "/home/njck/.local/lib/python3.10/site-packages/pip/_vendor/rich/console.py", line 1305, in render
#     for render_output in iter_render:
#   File "/home/njck/.local/lib/python3.10/site-packages/pip/_internal/utils/logging.py", line 134, in __rich_console__
#     for line in lines:
#   File "/home/njck/.local/lib/python3.10/site-packages/pip/_vendor/rich/segment.py", line 249, in split_lines
#     for segment in segments:
# ...

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd

# %%
p1 = [1,2,6,18]
p2 = [3,10,12,20]
plt.plot(p1,p2,marker='o',mfc='r',color='g')
plt.show()

# %%
plt.subplot(2,1,2)
plt.plot(p1,np.cos(p2))
plt.subplot(2,2,1)
plt.plot(p2,np.sin(p2))
plt.show()

# %%
x=pd.read_csv('ppp.csv')

# %%
plt.plot(x,marker='o')

# %%
la = np.array(['java','python','php','js','c#','c++'])
pop = np.array([22.2,17.6,8.8,8,7.7,6.7])
plt.barh(la,pop,color=['r','y','b','g','black','brown'])
# Out:
# <BarContainer object of 6 artists>

# %%
# Out:
# Text(0.5, 0, 'x - axis')

# %%
plt.scatter(la,pop)

# %%
plt.barh(la,pop)

# %%
plt.bar(la,pop,color=['r','g','y','b','m','brown'])

# %%
ll = ['java','python','php','js','c#','c++']
plt.pie(pop,labels=ll)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f9b96ae4700>,
# ...
#  [Text(0.6106212455488447, 0.914954476727874, 'java'),
#   Text(-1.0139237282141302, 0.4265661418401121, 'python'),
#   Text(-0.7897694469856671, -0.7656789278855424, 'php'),
#   Text(-0.06323929665114071, -1.0981806733680344, 'js'),
#   Text(0.654413852726294, -0.8841620379545417, 'c#'),
#   Text(1.0520142924916651, -0.3213501647630839, 'c++')])

# %%
n_groups = 5
men_means = (22, 30, 33, 30, 26)
women_means = (25, 32, 30, 35, 29)

# create plot
fig, ax = plt.subplots()
index = np.arange(n_groups)
print(index)
bar_width = 0.35
opacity = 0.8

rects1 = plt.bar(index, men_means, bar_width,
alpha=opacity,
color='g',
label='Men')
print(rects1)
rects2 = plt.bar(index + bar_width, women_means, bar_width,
alpha=opacity,
color='r',
label='Women')

plt.xlabel('Person')
plt.ylabel('Scores')
plt.title('Scores by person')
plt.xticks(index + bar_width, ('G1', 'G2', 'G3', 'G4', 'G5'))
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# [0 1 2 3 4]
# <BarContainer object of 5 artists>

# %%
import matplotlib.pyplot as plt
with open("test.txt") as f:
    data = f.read()
data = data.split('\n')
data=data[:-1]
print(data)
x = [row.split(' ')[0] for row in data]
print(x)
y = [row.split(' ')[1] for row in data]
plt.plot(x, y,marker='o')
print(y)
plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.title('Sample graph!')
plt.show()
# Out:
# ['1 3', '2 10', '6 12', '18 20']
# ['1', '2', '6', '18']
# ['3', '10', '12', '20']

# %%
x=[1,4,7]
y=[6,9,1]
x2=[2,9,11]
y2=[6,10,1]
plt.plot(x,y,label="first")
plt.plot(x2,y2,label="sec")
plt.legend()
plt.show()

# %%
x=[1,4,7]
y=[6,9,1]
x2=[2,9,11]
y2=[6,10,1]
plt.subplot(2,1,1)
plt.plot(x,y)
plt.show()
plt.subplot(2,3,4)
plt.plot(x2,y2)
plt.show()
